# %%
import xarray as xs
import os
import pywapor as pr

# %%
inpdir = 'C:/Mayank/Projects/Project_Viatris/Data/BiasCorrection/Corrected/RCP85/'
outdir = 'C:/Mayank/Projects/Project_Viatris/Data/BiasCorrection/Corrected/RCP85/Celcius/'

# %%
inpfile1 = 'tmean_without_leap_1990_2005.nc'
inpfile2 = 'tmean_without_leap_1991_2005_new.nc'
inpfile3 = 'tmean_without_leap_2000_2012_new.nc'

# %%
opfile1 = 'tmean_without_leap_1990_2005_new_kelvin.nc'
opfile2 = 'tmean_without_leap_1991_2005_new_kelvin.nc'
opfile3 = 'tmean_without_leap_2000_2012_new_kelvin.nc'

# %%
import glob

# %%
ifiles = glob.glob(os.path.join(inpdir, "*.nc"))

# %%
ifiles
# Out:
# ['C:/Mayank/Projects/Project_Viatris/Data/BiasCorrection/Corrected/RCP85\\CanESM_rcp85_2020_2040_corrected.nc',
#  'C:/Mayank/Projects/Project_Viatris/Data/BiasCorrection/Corrected/RCP85\\CCSM4_rcp85_2020_2040_corrected.nc',
#  'C:/Mayank/Projects/Project_Viatris/Data/BiasCorrection/Corrected/RCP85\\CESM1_CAM_rcp85_2020_2040_corrected.nc',
#  'C:/Mayank/Projects/Project_Viatris/Data/BiasCorrection/Corrected/RCP85\\EC_EARTH_rcp85_2020_2040_corrected.nc',
#  'C:/Mayank/Projects/Project_Viatris/Data/BiasCorrection/Corrected/RCP85\\GFDL_rcp85_2020_2040_corrected.nc',
#  'C:/Mayank/Projects/Project_Viatris/Data/BiasCorrection/Corrected/RCP85\\MIROC_rcp85_2020_2040_corrected.nc']

# %%
for f in ifiles:
    data = xs.open_dataset(f)
    basename = os.path.basename(f)
    datacelcius = pr.enhancers.temperature.kelvin_to_celsius(data, var='Tas')
    datacelcius.to_netcdf(os.path.join(outdir, basename))

# %%
imdmean = xs.open_dataset(os.path.join(inpdir,inpfile3))

# %%
imdmean
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 4745, lon: 31, lat: 31)
# Coordinates:
#   * time     (time) object 2000-01-01 00:00:00 ... 2012-12-31 00:00:00
#   * lon      (lon) float64 67.5 68.5 69.5 70.5 71.5 ... 93.5 94.5 95.5 96.5 97.5
#   * lat      (lat) float64 7.5 8.5 9.5 10.5 11.5 ... 33.5 34.5 35.5 36.5 37.5
# Data variables:
#     tmean    (time, lat, lon) float64 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.7
#     source:       https://imdpune.gov.in/
#     title:        IMD gridded data
#     history:      Thu Nov 16 14:01:12 2023: cdo del29feb tmean_2000_2012.nc t...
#     crs:          epsg:4326
#     CDO:          Climate Data Operators version 2.0.4 (https://mpimet.mpg.de...

# %%
imdmeankelvin = pr.enhancers.temperature.celsius_to_kelvin(imdmean, var='tmean')

# %%
imdmeankelvin
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 4745, lon: 31, lat: 31)
# Coordinates:
#   * time     (time) object 2000-01-01 00:00:00 ... 2012-12-31 00:00:00
#   * lon      (lon) float64 67.5 68.5 69.5 70.5 71.5 ... 93.5 94.5 95.5 96.5 97.5
#   * lat      (lat) float64 7.5 8.5 9.5 10.5 11.5 ... 33.5 34.5 35.5 36.5 37.5
# Data variables:
#     tmean    (time, lat, lon) float64 373.1 373.1 373.1 ... 373.1 373.1 373.1
# Attributes:
#     CDI:          Climate Data Interface version 2.0.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.7
#     source:       https://imdpune.gov.in/
#     title:        IMD gridded data
#     history:      Thu Nov 16 14:01:12 2023: cdo del29feb tmean_2000_2012.nc t...
#     crs:          epsg:4326
#     CDO:          Climate Data Operators version 2.0.4 (https://mpimet.mpg.de...

# %%
imdmeankelvin.to_netcdf(os.path.join(inpdir, opfile3))
