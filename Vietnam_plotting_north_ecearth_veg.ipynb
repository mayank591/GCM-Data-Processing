# %%
import rioxarray
import xarray as xs
import matplotlib.pyplot as plt
import os
import glob
import datetime
from netCDF4 import Dataset, num2date, date2num
import numpy as np
# %matplotlib inline
import pandas as pd
from calendar import isleap
from pandas.tseries.offsets import DateOffset
from pathlib import Path 
import seaborn as sns

# %%
region='North'

# %%
folder = "C:/Mayank/Projects/Project_Vietnam/NewData/GCM_Download/ECEARTH_Veg/Merged/Clipped/Unit_Changed/Regional"

# %%
ds1 = xs.open_dataset(os.path.join(folder, "ssp585_tas_ecearth_veg_final_"+region+".nc"))

# %%
ds2 = xs.open_dataset(os.path.join(folder, "ssp245_tas_ecearth_veg_final_"+region+".nc"))

# %%
fig,ax = plt.subplots(figsize=(10,7))
ds1.tas.groupby('time.year').mean(['time','lon','lat']).plot(ax=ax,label='SSP585')
ds2.tas.groupby('time.year').mean(['time','lon','lat']).plot(ax=ax,label='SSP245')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.0),
          ncol=4, fancybox=True, shadow=True)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,7))
ds1.tas.groupby('time.month').mean(['time','lon','lat']).plot(ax=ax,label='SSP585')
ds2.tas.groupby('time.month').mean(['time','lon','lat']).plot(ax=ax,label='SSP245')
ax.legend(loc='center ', bbox_to_anchor=(0.5, 1.0),
          ncol=4, fancybox=True, shadow=True)
plt.show()

# %%
ds3 = xs.open_dataset(os.path.join(folder, "ssp585_pr_ecearth_veg_final_"+region+".nc"))

# %%
ds4 = xs.open_dataset(os.path.join(folder, "ssp245_pr_ecearth_veg_final_"+region+".nc"))

# %%
fig,ax = plt.subplots(figsize=(10,7))
ds3.pr.groupby('time.year').sum(['time','lon','lat']).plot(ax=ax,label='SSP585')
ds4.pr.groupby('time.year').sum(['time','lon','lat']).plot(ax=ax,label='SSP245')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.0),
          ncol=4, fancybox=True, shadow=True)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,7))
ds3.pr.groupby('time.month').sum(['time','lon','lat']).plot(ax=ax,label='SSP585')
ds4.pr.groupby('time.month').sum(['time','lon','lat']).plot(ax=ax,label='SSP245')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.0),
          ncol=4, fancybox=True, shadow=True)
plt.show()
