# %%
import rioxarray
import xarray as xs
import matplotlib.pyplot as plt
import os
import glob
import datetime
from netCDF4 import Dataset, num2date, date2num
import numpy as np
# %matplotlib inline
import pandas as pd
from calendar import isleap
from pandas.tseries.offsets import DateOffset
from pathlib import Path 
import seaborn as sns
# import nctoolkit as nc

# %%
region='South'

# %%
folder = "C:/Mayank/Projects/Project_Vietnam/NewData/GCM_Download/ECEARTH3/Merged/Clipped/Unit_Changed/Regional"

# %%
ds1 = xs.open_dataset(os.path.join(folder, "ssp585_tas_ecearth3_final_"+region+".nc"))

# %%
ds2 = xs.open_dataset(os.path.join(folder, "ssp245_tas_ecearth3_final_"+region+".nc"))

# %%
fig,ax = plt.subplots(figsize=(10,7))
ds1.tas.groupby('time.year').mean(['time','lon','lat']).plot(ax=ax,label='SSP585')
ds2.tas.groupby('time.year').mean(['time','lon','lat']).plot(ax=ax,label='SSP245')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.0),
          ncol=4, fancybox=True, shadow=True)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,7))
ds1.tas.groupby('time.month').mean(['time','lon','lat']).plot(ax=ax,label='SSP585')
ds2.tas.groupby('time.month').mean(['time','lon','lat']).plot(ax=ax,label='SSP245')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.0),
          ncol=4, fancybox=True, shadow=True)
plt.show()

# %%
ds3 = xs.open_dataset(os.path.join(folder, "ssp585_pr_ecearth3_final_"+region+".nc"))
# ds3.pr.attrs['units']='mm'
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\xarray\backends\plugins.py:71: RuntimeWarning: Engine 'gini' loading failed:
# cannot import name 'deprecated' from 'typing_extensions' (C:\ProgramData\anaconda3\lib\site-packages\typing_extensions.py)
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
ds4 = xs.open_dataset(os.path.join(folder, "ssp245_pr_ecearth3_final_"+region+".nc"))
# ds4.pr.attrs['units'] = 'mm'

# %%
fig,ax = plt.subplots(figsize=(10,7))
ds3.pr.groupby('time.year').mean(['time','lon','lat']).plot(ax=ax,label='SSP585')
ds4.pr.groupby('time.year').mean(['time','lon','lat']).plot(ax=ax,label='SSP245')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.0),
          ncol=4, fancybox=True, shadow=True)
trend = np.polyfit(np.arange(1,22), ds3.pr.groupby('time.year').mean(['time','lon','lat']), 1)
print(trend)
plt.show()
# Out:
# [-0.00902312  5.63381169]

# %%
fig,ax = plt.subplots(figsize=(10,7))
ds3.pr.groupby('time.month').mean(['time','lon','lat']).plot(ax=ax,label='SSP585')
ds4.pr.groupby('time.month').mean(['time','lon','lat']).plot(ax=ax,label='SSP245')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.0),
          ncol=4, fancybox=True, shadow=True)
plt.show()
