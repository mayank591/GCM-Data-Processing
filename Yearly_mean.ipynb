# %%
import xarray

# %%
tmax = xarray.open_dataset('C:/Mayank/Projects/Project_Viatris/Data/Rainfall_Temperature/New_IMD/Temperature/tmax1970_2022.nc')
tmin = xarray.open_dataset('C:/Mayank/Projects/Project_Viatris/Data/Rainfall_Temperature/New_IMD/Temperature/tmin1970_2022.nc')
# rain = xarray.open_dataset("C:/Mayank/Projects/Project_Viatris/Data/Rainfall_Temperature/New_IMD/Rainfall/Rainfall1deg/rainfall_1deg_1970_2022.nc")

# %%
tmax
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 19358, lat: 31, lon: 31)
# Coordinates:
#   * lat      (lat) float64 7.5 8.5 9.5 10.5 11.5 ... 33.5 34.5 35.5 36.5 37.5
#   * lon      (lon) float64 67.5 68.5 69.5 70.5 71.5 ... 93.5 94.5 95.5 96.5 97.5
#   * time     (time) datetime64[ns] 1970-01-01 1970-01-02 ... 2022-12-31
# Data variables:
#     tmax     (time, lat, lon) float64 ...
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2023-11-06 16:46:15.906212 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
rain
# Out:
# <xarray.Dataset>
# Dimensions:    (LONGITUDE: 35, LATITUDE: 33, TIME: 19358)
# Coordinates:
#   * LONGITUDE  (LONGITUDE) float64 66.5 67.5 68.5 69.5 ... 97.5 98.5 99.5 100.5
#   * LATITUDE   (LATITUDE) float64 6.5 7.5 8.5 9.5 10.5 ... 35.5 36.5 37.5 38.5
#   * TIME       (TIME) datetime64[ns] 1970-01-01 1970-01-02 ... 2022-12-31
# Data variables:
#     RAINFALL   (TIME, LATITUDE, LONGITUDE) float64 ...
# Attributes:
#     history:      FERRET V7.5 (optimized) 28-Mar-22
#     Conventions:  CF-1.6

# %%
ds=rain.groupby('TIME.year').mean('TIME')

# %%
len(rain.to_dataframe())
# Out:
# 22358490

# %%
len(ds.to_dataframe())
# Out:
# 61215

# %%
tmax=xarray.open_dataset('C:/Mayank/Extra/IMD/Temperature/tmax1970_2022.nc')
tmin=xarray.open_dataset('C:/Mayank/Extra/IMD/Temperature/tmin1970_2022.nc')
# tmax=xarray.open_dataset('C:/Mayank/Extra/IMD/Temperature/tmax1990_2005.nc')
# tmin=xarray.open_dataset('C:/Mayank/Extra/IMD/Temperature/tmin1990_2005.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\xarray\backends\file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     208             try:
# --> 209                 file = self._cache[self._key]
#     210             except KeyError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\xarray\backends\lru_cache.py in __getitem__(self, key)
#      54         with self._lock:
# ---> 55             value = self._cache[key]
#      56             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('C:\\Mayank\\Extra\\IMD\\Temperature\\tmax1990_2005.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'c370e308-02f3-41e0-b598-d016d8138c5d']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
ds1=tmax.groupby('time.year').mean('time')

# %%
ds2=tmin.groupby('time.year').mean('time')

# %%
dsmerged = xarray.merge([ds1,ds2])
# dsmerged = xarray.merge([tmax,tmin])

# %%
tmean=(dsmerged['tmax']+dsmerged['tmin'])/2

# %%
tmean
# Out:
# <xarray.DataArray (year: 53, lat: 31, lon: 31)>
# array([[[99.90000153, 99.90000153, 99.90000153, ..., 99.90000153,
#          99.90000153, 99.90000153],
#         [99.90000153, 99.90000153, 99.90000153, ..., 99.90000153,
#          99.90000153, 99.90000153],
#         [99.90000153, 99.90000153, 99.90000153, ..., 99.90000153,
#          99.90000153, 99.90000153],
#         ...,
#         [99.90000153, 99.90000153, 99.90000153, ..., 99.90000153,
#          99.90000153, 99.90000153],
#         [99.90000153, 99.90000153, 99.90000153, ..., 99.90000153,
#          99.90000153, 99.90000153],
#         [99.90000153, 99.90000153, 99.90000153, ..., 99.90000153,
#          99.90000153, 99.90000153]],
#
#        [[99.90000153, 99.90000153, 99.90000153, ..., 99.90000153,
#          99.90000153, 99.90000153],
#         [99.90000153, 99.90000153, 99.90000153, ..., 99.90000153,
#          99.90000153, 99.90000153],
#         [99.90000153, 99.90000153, 99.90000153, ..., 99.90000153,
# ...

# %%
dsmerged['tmean']=tmean

# %%
newds=dsmerged.drop(['tmin','tmax'])

# %%
newds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 31, lon: 31, year: 53)
# Coordinates:
#   * lat      (lat) float64 7.5 8.5 9.5 10.5 11.5 ... 33.5 34.5 35.5 36.5 37.5
#   * lon      (lon) float64 67.5 68.5 69.5 70.5 71.5 ... 93.5 94.5 95.5 96.5 97.5
#   * year     (year) int64 1970 1971 1972 1973 1974 ... 2018 2019 2020 2021 2022
# Data variables:
#     tmean    (year, lat, lon) float64 99.9 99.9 99.9 99.9 ... 99.9 99.9 99.9
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2023-11-06 16:46:15.906212 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
forcsv=newds.to_dataframe()

# %%
# forcsv.to_csv('C:/Mayank/Extra/IMD/Temperature/tmean_1990_2005.csv')
newds.to_netcdf('C:/Mayank/Projects/Project_Viatris/Data/Rainfall_Temperature/New_IMD/Temperature/tmean_1970_2022.nc')
# ds.to_netcdf("C:/Mayank/Projects/Project_Viatris/Data/Rainfall_Temperature/New_IMD/Rainfall/Rainfall1deg/rainfall_yearlymean_1970_2022.nc")
